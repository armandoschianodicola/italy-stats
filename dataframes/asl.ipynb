# %%
import os
import sys
import pandas as pd

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from utils import path_utils, header_formatter, name_formatter

# %%
pathUtils = path_utils.PathUtils()

# %%
git_root_path = pathUtils.get_git_root(os.getcwd())
datasets_path = "{}/datasets".format(git_root_path)

# %%
# %run ../datasets/sigle_province.ipynb -i

# %%
cities_info
# Out:
# {'napoli': {'acronym': 'NA'},
#  'pozzuoli': {'acronym': 'NA'},
#  'castellammare di stabia': {'acronym': 'NA'},
#  'torre del greco': {'acronym': 'NA'},
#  'frattamaggiore': {'acronym': 'NA'}}

# %%
cities_acronyms = {k: v.get("acronym") for k,v in cities_info.items()}

# %% [markdown]
# # Prepare dataframe

# %%
df_asl = pd.read_csv(
    '../datasets/C_17_dataset_2_0_upFile.csv',
    delimiter=";",
    encoding = "ISO-8859-1",
)

# %%
headers_formatter = header_formatter.HeaderFormatter(df_asl)

# %%
headers_formatter.format()

# %%
col_formatter = name_formatter.NameFormatter(df_asl)

# %%
col_formatter.format("denominazione_azienda")

# %%
df_asl
# Out:
#       anno  codice_regione denominazione_regione  codice_azienda  \
# 0     2010              10              PIEMONTE             201
# 1     2010              10              PIEMONTE             202
# 2     2010              10              PIEMONTE             203
# 3     2010              10              PIEMONTE             204
# 4     2010              10              PIEMONTE             205
# ...    ...             ...                   ...             ...
# 1801  2024             200              SARDEGNA             304
# 1802  2024             200              SARDEGNA             305
# 1803  2024             200              SARDEGNA             306
# 1804  2024             200              SARDEGNA             307
# 1805  2024             200              SARDEGNA             308
#
#              denominazione_azienda                        indirizzo    cap  \
# 0                              to1           VIA S.SECONDO 29        10128
# 1                              to2          CORSO SVIZZERA 164       10149
# 2                              to3  VIA MARTIRI XXX APRILE 30        10093
# 3                              to4                  Via Po 11        10034
# 4                              to5        VIA SAN DOMENICO 21        10023
# ...                            ...                              ...    ...
# 1801       asl n. 4 dell'ogliastra                   VIA PISCINAS 1   8045
# 1802          asl n. 5 di oristano                  VIA CARDUCCI 35   9170
# 1803  asl n. 6 del medio campidano         VIA GIUSEPPE UNGARETTI 9   9025
# 1804           asl n. 7 del sulcis                  VIA DALMAZIA 83   9013
# 1805          asl n. 8 di cagliari    PO MARINO-LUNGOMARE POETTO 12   9126
#
#         comune sigla_provincia     telefono          fax  \
# 0       TORINO              TO          NaN          NaN
# 1       TORINO              TO          NaN          NaN
# 2     COLLEGNO              TO          NaN          NaN
# 3     CHIVASSO              TO          NaN          NaN
# 4       CHIERI              TO          NaN          NaN
# ...        ...             ...          ...          ...
# 1801   LANUSEI              NU          NaN          NaN
# 1802  ORISTANO              OR          NaN          NaN
# 1803   SANLURI              SU     07093841     07093841
# 1804  CARBONIA              SU     07816681     07816681
# 1805  CAGLIARI              CA  070/6097941  070/6097941
#
#                                        e-mail                  sito_web  \
# 0                                         NaN                       NaN
# 1                                         NaN                       NaN
# 2                                         NaN                       NaN
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
# ...                                       ...                       ...
# 1801       direzione.generale@aslogliastra.it       www.aslogliastra.it
# 1802        direzione.generale@asloristano.it    nuovo.asloristano.it/a
# 1803  direzione.generale@aslmediocampidano.it  www.aslmediocampidano.it
# 1804          direzione.generale@aslsulcis.it          www.aslsulcis.it
# 1805        direzione.generale@aslcagliari.it    nuovo.aslcagliari.it/a
#
#        partita_iva
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1801  1.620421e+09
# 1802  1.258181e+09
# 1803  3.990321e+09
# 1804  3.990311e+09
# 1805  3.990561e+09
#
# [1806 rows x 14 columns]

# %%
df_asl.loc[(df_asl["comune"] == "LIVORNO"), ]
# Out:
#      anno  codice_regione denominazione_regione  codice_azienda  \
# 79   2010              90               TOSCANA             106
# 225  2011              90               TOSCANA             106
# 370  2012              90               TOSCANA             106
# 515  2013              90               TOSCANA             106
# 655  2014              90               TOSCANA             106
# 794  2015              90               TOSCANA             106
#
#     denominazione_azienda                  indirizzo    cap   comune  \
# 79                livorno        VIA MONTEROTONDO 49  57100  LIVORNO
# 225               livorno        VIA MONTEROTONDO 49  57100  LIVORNO
# 370               livorno  VIA MONTEROTONDO 49        57100  LIVORNO
# 515               livorno  VIA MONTEROTONDO 49        57100  LIVORNO
# 655               livorno  VIA MONTEROTONDO 49        57100  LIVORNO
# 794               livorno  VIA MONTEROTONDO 49        57100  LIVORNO
#
#     sigla_provincia telefono  fax e-mail sito_web  partita_iva
# 79               LI      NaN  NaN    NaN      NaN          NaN
# 225              LI      NaN  NaN    NaN      NaN          NaN
# 370              LI      NaN  NaN    NaN      NaN          NaN
# 515              LI      NaN  NaN    NaN      NaN          NaN
# 655              LI      NaN  NaN    NaN      NaN          NaN
# 794              LI      NaN  NaN    NaN      NaN          NaN

# %%
df_asl[df_asl['sigla_provincia'].isna()]
# Out:
#       anno  codice_regione denominazione_regione  codice_azienda  \
# 111   2010             150              CAMPANIA             204
# 112   2010             150              CAMPANIA             205
# 113   2010             150              CAMPANIA             206
# 257   2011             150              CAMPANIA             204
# 258   2011             150              CAMPANIA             205
# 259   2011             150              CAMPANIA             206
# 402   2012             150              CAMPANIA             204
# 403   2012             150              CAMPANIA             205
# 404   2012             150              CAMPANIA             206
# 545   2013             150              CAMPANIA             204
# 546   2013             150              CAMPANIA             205
# 547   2013             150              CAMPANIA             206
# 685   2014             150              CAMPANIA             204
# 686   2014             150              CAMPANIA             205
# 687   2014             150              CAMPANIA             206
# 824   2015             150              CAMPANIA             204
# 825   2015             150              CAMPANIA             205
# 826   2015             150              CAMPANIA             206
# 945   2016             150              CAMPANIA             204
# 946   2016             150              CAMPANIA             205
# 947   2016             150              CAMPANIA             206
# 1053  2017             150              CAMPANIA             204
# 1054  2017             150              CAMPANIA             205
# 1055  2017             150              CAMPANIA             206
# 1154  2018             150              CAMPANIA             204
# 1155  2018             150              CAMPANIA             205
# 1156  2018             150              CAMPANIA             206
# 1255  2019             150              CAMPANIA             204
# 1256  2019             150              CAMPANIA             205
# 1257  2019             150              CAMPANIA             206
# 1354  2020             150              CAMPANIA             204
# 1355  2020             150              CAMPANIA             205
# 1356  2020             150              CAMPANIA             206
# 1453  2021             150              CAMPANIA             204
# 1454  2021             150              CAMPANIA             205
# 1455  2021             150              CAMPANIA             206
# 1552  2022             150              CAMPANIA             204
# 1553  2022             150              CAMPANIA             205
# 1554  2022             150              CAMPANIA             206
# 1662  2023             150              CAMPANIA             204
# 1663  2023             150              CAMPANIA             205
# 1664  2023             150              CAMPANIA             206
# 1772  2024             150              CAMPANIA             204
# 1773  2024             150              CAMPANIA             205
# 1774  2024             150              CAMPANIA             206
#
#        denominazione_azienda                           indirizzo    cap  \
# 111   a.s.l. napoli 1 centro         CENTRO DIREZIONALE IS. F/9   80143
# 112     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 113      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 257   a.s.l. napoli 1 centro         CENTRO DIREZIONALE IS. F/9   80143
# 258     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 259      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 402   a.s.l. napoli 1 centro         CENTRO DIREZIONALE IS. F/9   80143
# 403     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 404      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 545   a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 546     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 547      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 685   a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 686     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 687      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 824   a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 825     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 826      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 945   a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 946     a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 947      a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 1053  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1054    a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 1055     a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 1154  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1155    a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 1156     a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 1255  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1256    a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 1257     a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 1354  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1355    a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 1356     a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 1453  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1454    a.s.l. napoli 2 nord         VIA CORRADO ALVARO 8         80078
# 1455     a.s.l. napoli 3 sud     C.SO ALCIDE DE GASPERI 167       80053
# 1552  a.s.l. napoli 1 centro  VIA COMUNALE DEL PRINCIPE 13/a      80145
# 1553    a.s.l. napoli 2 nord                 VIA LUPOLI 27        80027
# 1554     a.s.l. napoli 3 sud                VIA MARCONI 66        80059
# 1662  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1663    a.s.l. napoli 2 nord                       VIA LUPOLI 27  80027
# 1664     a.s.l. napoli 3 sud                      VIA MARCONI 66  80059
# 1772  a.s.l. napoli 1 centro  Via Comunale del Principe 13/a      80145
# 1773    a.s.l. napoli 2 nord                       VIA LUPOLI 27  80027
# 1774     a.s.l. napoli 3 sud                      VIA MARCONI 66  80059
#
#                        comune sigla_provincia     telefono          fax  \
# 111                    NAPOLI             NaN          NaN          NaN
# 112                  POZZUOLI             NaN          NaN          NaN
# 113   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 257                    NAPOLI             NaN          NaN          NaN
# 258                  POZZUOLI             NaN          NaN          NaN
# 259   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 402                    NAPOLI             NaN          NaN          NaN
# 403                  POZZUOLI             NaN          NaN          NaN
# 404   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 545                    NAPOLI             NaN          NaN          NaN
# 546                  POZZUOLI             NaN          NaN          NaN
# 547   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 685                    NAPOLI             NaN          NaN          NaN
# 686                  POZZUOLI             NaN          NaN          NaN
# 687   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 824                    NAPOLI             NaN          NaN          NaN
# 825                  POZZUOLI             NaN          NaN          NaN
# 826   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 945                    NAPOLI             NaN          NaN          NaN
# 946                  POZZUOLI             NaN          NaN          NaN
# 947   CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 1053                   NAPOLI             NaN          NaN          NaN
# 1054                 POZZUOLI             NaN          NaN          NaN
# 1055  CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 1154                   NAPOLI             NaN          NaN          NaN
# 1155                 POZZUOLI             NaN          NaN          NaN
# 1156  CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 1255                   NAPOLI             NaN          NaN          NaN
# 1256                 POZZUOLI             NaN          NaN          NaN
# 1257  CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 1354                   NAPOLI             NaN          NaN          NaN
# 1355                 POZZUOLI             NaN          NaN          NaN
# 1356  CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 1453                   NAPOLI             NaN          NaN          NaN
# 1454                 POZZUOLI             NaN          NaN          NaN
# 1455  CASTELLAMMARE DI STABIA             NaN          NaN          NaN
# 1552                   NAPOLI             NaN          NaN          NaN
# 1553           FRATTAMAGGIORE             NaN          NaN          NaN
# 1554          TORRE DEL GRECO             NaN          NaN          NaN
# 1662                   NAPOLI             NaN          NaN          NaN
# 1663           FRATTAMAGGIORE             NaN          NaN          NaN
# 1664          TORRE DEL GRECO             NaN          NaN          NaN
# 1772                   NAPOLI             NaN  081 2541111  081 2544798
# 1773           FRATTAMAGGIORE             NaN  081 8552111  081 5249308
# 1774          TORRE DEL GRECO             NaN  081 8729751  081 8729776
#
#                                     e-mail               sito_web  \
# 111                                    NaN                    NaN
# 112                                    NaN                    NaN
# 113                                    NaN                    NaN
# 257                                    NaN                    NaN
# 258                                    NaN                    NaN
# 259                                    NaN                    NaN
# 402                                    NaN                    NaN
# 403                                    NaN                    NaN
# 404                                    NaN                    NaN
# 545                                    NaN                    NaN
# 546                                    NaN                    NaN
# 547                                    NaN                    NaN
# 685                                    NaN                    NaN
# 686                                    NaN                    NaN
# 687                                    NaN                    NaN
# 824                                    NaN                    NaN
# 825                                    NaN                    NaN
# 826                                    NaN                    NaN
# 945                                    NaN                    NaN
# 946                                    NaN                    NaN
# 947                                    NaN                    NaN
# 1053                                   NaN                    NaN
# 1054                                   NaN                    NaN
# 1055                                   NaN                    NaN
# 1154                                   NaN                    NaN
# 1155                                   NaN                    NaN
# 1156                                   NaN                    NaN
# 1255                                   NaN                    NaN
# 1256                                   NaN                    NaN
# 1257                                   NaN                    NaN
# 1354                                   NaN                    NaN
# 1355                                   NaN                    NaN
# 1356                                   NaN                    NaN
# 1453                                   NaN                    NaN
# 1454                                   NaN                    NaN
# 1455                                   NaN                    NaN
# 1552                                   NaN                    NaN
# 1553                                   NaN                    NaN
# 1554                                   NaN                    NaN
# 1662                                   NaN                    NaN
# 1663                                   NaN                    NaN
# 1664                                   NaN                    NaN
# 1772  aslnapoli1centro@pec.aslna1centro.it   www.aslna1.napoli.it
# 1773   direzionegenerale@aslnapoli2nord.it  www.aslnapoli2nord.it
# 1774       protocollo@pec.aslnapoli3sud.it   www.aslnapoli3sud.it
#
#        partita_iva
# 111            NaN
# 112            NaN
# 113            NaN
# 257            NaN
# 258            NaN
# 259            NaN
# 402            NaN
# 403            NaN
# 404            NaN
# 545            NaN
# 546            NaN
# 547            NaN
# 685            NaN
# 686            NaN
# 687            NaN
# 824            NaN
# 825            NaN
# 826            NaN
# 945            NaN
# 946            NaN
# 947            NaN
# 1053           NaN
# 1054           NaN
# 1055           NaN
# 1154           NaN
# 1155           NaN
# 1156           NaN
# 1255           NaN
# 1256           NaN
# 1257           NaN
# 1354           NaN
# 1355           NaN
# 1356           NaN
# 1453           NaN
# 1454           NaN
# 1455           NaN
# 1552           NaN
# 1553           NaN
# 1554           NaN
# 1662           NaN
# 1663           NaN
# 1664           NaN
# 1772  6.328131e+09
# 1773  6.321661e+09
# 1774  6.322711e+09

# %%
df_asl["comune"].str.lower()
# Out:
# 0         torino
# 1         torino
# 2       collegno
# 3       chivasso
# 4         chieri
#           ...
# 1801     lanusei
# 1802    oristano
# 1803     sanluri
# 1804    carbonia
# 1805    cagliari
# Name: comune, Length: 1806, dtype: object

# %%
 missing_mask_sigla_provincia = df_asl['sigla_provincia'].isna()

# %%
df_asl.loc[missing_mask_sigla_provincia, 'sigla_provincia'] = df_asl.loc[missing_mask_sigla_provincia, 'comune'].str.lower().map(cities_acronyms)

# %%
df_asl[df_asl['sigla_provincia'].isna()]
# Out:
# Empty DataFrame
# Columns: [anno, codice_regione, denominazione_regione, codice_azienda, denominazione_azienda, indirizzo, cap, comune, sigla_provincia, telefono, fax, e-mail, sito_web, partita_iva]
# Index: []

# %%
df_asl
# Out:
#       anno  codice_regione denominazione_regione  codice_azienda  \
# 0     2010              10              PIEMONTE             201
# 1     2010              10              PIEMONTE             202
# 2     2010              10              PIEMONTE             203
# 3     2010              10              PIEMONTE             204
# 4     2010              10              PIEMONTE             205
# ...    ...             ...                   ...             ...
# 1801  2024             200              SARDEGNA             304
# 1802  2024             200              SARDEGNA             305
# 1803  2024             200              SARDEGNA             306
# 1804  2024             200              SARDEGNA             307
# 1805  2024             200              SARDEGNA             308
#
#              denominazione_azienda                        indirizzo    cap  \
# 0                              to1           VIA S.SECONDO 29        10128
# 1                              to2          CORSO SVIZZERA 164       10149
# 2                              to3  VIA MARTIRI XXX APRILE 30        10093
# 3                              to4                  Via Po 11        10034
# 4                              to5        VIA SAN DOMENICO 21        10023
# ...                            ...                              ...    ...
# 1801       asl n. 4 dell'ogliastra                   VIA PISCINAS 1   8045
# 1802          asl n. 5 di oristano                  VIA CARDUCCI 35   9170
# 1803  asl n. 6 del medio campidano         VIA GIUSEPPE UNGARETTI 9   9025
# 1804           asl n. 7 del sulcis                  VIA DALMAZIA 83   9013
# 1805          asl n. 8 di cagliari    PO MARINO-LUNGOMARE POETTO 12   9126
#
#         comune sigla_provincia     telefono          fax  \
# 0       TORINO              TO          NaN          NaN
# 1       TORINO              TO          NaN          NaN
# 2     COLLEGNO              TO          NaN          NaN
# 3     CHIVASSO              TO          NaN          NaN
# 4       CHIERI              TO          NaN          NaN
# ...        ...             ...          ...          ...
# 1801   LANUSEI              NU          NaN          NaN
# 1802  ORISTANO              OR          NaN          NaN
# 1803   SANLURI              SU     07093841     07093841
# 1804  CARBONIA              SU     07816681     07816681
# 1805  CAGLIARI              CA  070/6097941  070/6097941
#
#                                        e-mail                  sito_web  \
# 0                                         NaN                       NaN
# 1                                         NaN                       NaN
# 2                                         NaN                       NaN
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
# ...                                       ...                       ...
# 1801       direzione.generale@aslogliastra.it       www.aslogliastra.it
# 1802        direzione.generale@asloristano.it    nuovo.asloristano.it/a
# 1803  direzione.generale@aslmediocampidano.it  www.aslmediocampidano.it
# 1804          direzione.generale@aslsulcis.it          www.aslsulcis.it
# 1805        direzione.generale@aslcagliari.it    nuovo.aslcagliari.it/a
#
#        partita_iva
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 1801  1.620421e+09
# 1802  1.258181e+09
# 1803  3.990321e+09
# 1804  3.990311e+09
# 1805  3.990561e+09
#
# [1806 rows x 14 columns]

# %%
git_root_path = pathUtils.get_git_root(os.getcwd())

# %%
dataframes_path = "{}/dataframes".format(git_root_path)

# %%
df_asl.to_pickle("{}/df_asl.pkl".format(dataframes_path))
