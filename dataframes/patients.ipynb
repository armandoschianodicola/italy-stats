# %%
import os
import sys

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from utils import region_formatter

# %%
df_patients = pd.read_csv(
    '../datasets/C_17_dataset_190_0_upFile.csv',
    delimiter=";",
    skiprows=3,
    keep_default_na=False)

# %%
df_patients
# Out:
#       Anno  Codice regione Descrizione Regione  Codice ASL  \
# 0     2022              10            PIEMONTE         203
# 1     2022              10            PIEMONTE         203
# 2     2022              10            PIEMONTE         203
# 3     2022              10            PIEMONTE         203
# 4     2022              10            PIEMONTE         203
# ...    ...             ...                 ...         ...
# 2775  2022             200            SARDEGNA         201
# 2776  2022             200            SARDEGNA         201
# 2777  2022             200            SARDEGNA         201
# 2778  2022             200            SARDEGNA         302
# 2779  2022             200            SARDEGNA         305
#
#                                      ASL                     SERD  \
# 0                                    TO3  A12
# 1                                    TO3  B01
# 2                                    TO3  B03
# 3                                    TO3  S01
# 4                                    TO3  S02
# ...                                  ...                      ...
# 2775  AZIENDA PER LA TUTELA DELLA SALUTE  S12
# 2776  AZIENDA PER LA TUTELA DELLA SALUTE  S14
# 2777  AZIENDA PER LA TUTELA DELLA SALUTE  S21
# 2778              ASL N. 2 DELLA GALLURA  S06
# 2779                ASL N. 5 DI ORISTANO  S14
#
#      Categoria Sostanza Utenti
# 0              OPPIACEI      1
# 1              OPPIACEI      3
# 2              OPPIACEI     40
# 3              OPPIACEI    124
# 4              OPPIACEI    104
# ...                 ...    ...
# 2775     ALTRE SOSTANZE
# 2776     ALTRE SOSTANZE
# 2777     ALTRE SOSTANZE
# 2778     ALTRE SOSTANZE      1
# 2779     ALTRE SOSTANZE      1
#
# [2780 rows x 8 columns]

# %%
df_patients.dtypes
# Out:
# Anno                    int64
# Codice regione          int64
# Descrizione Regione    object
# Codice ASL              int64
# ASL                    object
# SERD                   object
# Categoria Sostanza     object
# Utenti                 object
# dtype: object

# %%
df_patients = df_patients.replace(r'^\s*$', np.nan, regex=True)

# %%
df_patients["Utenti"] = df_patients["Utenti"].astype(float)

# %%
df_patients["Descrizione Regione"].unique()
# Out:
# array(['PIEMONTE', "VALLE D'AOSTA", 'LOMBARDIA', 'PROV. AUTON. BOLZANO',
#        'PROV. AUTON. TRENTO', 'VENETO', 'FRIULI VENEZIA GIULIA',
#        'LIGURIA', 'EMILIA ROMAGNA', 'TOSCANA', 'UMBRIA', 'MARCHE',
#        'LAZIO', 'ABRUZZO', 'MOLISE', 'CAMPANIA', 'PUGLIA', 'BASILICATA',
#        'CALABRIA', 'SICILIA', 'SARDEGNA'], dtype=object)

# %%
formatter = region_formatter.RegionFormatter(df_patients)

# %%
formatter.format("Descrizione Regione")

# %%
df_patients["Descrizione Regione"].unique()
# Out:
# array(['piemonte', "valle d'aosta", 'lombardia', 'trentino alto adige',
#        'veneto', 'friuli venezia giulia', 'liguria', 'emilia romagna',
#        'toscana', 'umbria', 'marche', 'lazio', 'abruzzo', 'molise',
#        'campania', 'puglia', 'basilicata', 'calabria', 'sicilia',
#        'sardegna'], dtype=object)

# %%
df_patients
# Out:
#       Anno  Codice regione Descrizione Regione  Codice ASL  \
# 0     2022              10            piemonte         203
# 1     2022              10            piemonte         203
# 2     2022              10            piemonte         203
# 3     2022              10            piemonte         203
# 4     2022              10            piemonte         203
# ...    ...             ...                 ...         ...
# 2775  2022             200            sardegna         201
# 2776  2022             200            sardegna         201
# 2777  2022             200            sardegna         201
# 2778  2022             200            sardegna         302
# 2779  2022             200            sardegna         305
#
#                                      ASL                     SERD  \
# 0                                    TO3  A12
# 1                                    TO3  B01
# 2                                    TO3  B03
# 3                                    TO3  S01
# 4                                    TO3  S02
# ...                                  ...                      ...
# 2775  AZIENDA PER LA TUTELA DELLA SALUTE  S12
# 2776  AZIENDA PER LA TUTELA DELLA SALUTE  S14
# 2777  AZIENDA PER LA TUTELA DELLA SALUTE  S21
# 2778              ASL N. 2 DELLA GALLURA  S06
# 2779                ASL N. 5 DI ORISTANO  S14
#
#      Categoria Sostanza  Utenti
# 0              OPPIACEI     1.0
# 1              OPPIACEI     3.0
# 2              OPPIACEI    40.0
# 3              OPPIACEI   124.0
# 4              OPPIACEI   104.0
# ...                 ...     ...
# 2775     ALTRE SOSTANZE     NaN
# 2776     ALTRE SOSTANZE     NaN
# 2777     ALTRE SOSTANZE     NaN
# 2778     ALTRE SOSTANZE     1.0
# 2779     ALTRE SOSTANZE     1.0
#
# [2780 rows x 8 columns]

# %%
df_patients = df_patients.rename(columns={
    "Descrizione Regione": "reg_name",
})

# %%
df_patients_regions_agg = df_patients.groupby([
    'reg_name',
])["Utenti"].sum().reset_index(name="users_sum")

# %%
df_patients_regions_agg
# Out:
#                  reg_name  users_sum
# 0                 abruzzo     3241.0
# 1              basilicata     1176.0
# 2                calabria     3090.0
# 3                campania     8462.0
# 4          emilia romagna     9139.0
# 5   friuli venezia giulia     1983.0
# 6                   lazio    11767.0
# 7                 liguria     3969.0
# 8               lombardia    23161.0
# 9                  marche     4962.0
# 10                 molise      764.0
# 11               piemonte    11971.0
# 12                 puglia     9059.0
# 13               sardegna     3329.0
# 14                sicilia     6648.0
# 15                toscana    10265.0
# 16    trentino alto adige     2134.0
# 17                 umbria     2753.0
# 18          valle d'aosta      281.0
# 19                 veneto    11105.0

# %%
df_patients_regions_agg.to_pickle("{}/df_patients_regions_agg.pkl".format(os.getcwd()))
