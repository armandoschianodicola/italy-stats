# %%
import csv

# %%
denominazione_azienda_map = {}

# %%
try:

    # name of csv file
    filename = "../datasets/denominazione_azienda_mapper.csv"

    with open(filename, mode='r') as infile:
        reader = csv.reader(infile, delimiter=";")
        next(reader, None)
        for row in reader:
            if row:
                old = row[0].lower().strip()
                new = row[1].lower().strip()
                denominazione_azienda_map[old] = new
    
except Exception as e:
    print(e)
    print("Error")

# %%
denominazione_azienda_map
# Out:
# {'pistoia': 'azienda usl toscana centro',
#  'prato': 'azienda usl toscana centro',
#  'empoli': 'azienda usl toscana centro',
#  'firenze': 'azienda usl toscana centro',
#  'lucca': 'azienda usl toscana nord-ovest',
#  'pisa': 'azienda usl toscana nord-ovest',
#  'livorno': 'azienda usl toscana nord-ovest',
#  'massa carrara': 'azienda usl toscana nord-ovest',
#  'versilia': 'azienda usl toscana nord-ovest',
#  'arezzo': 'azienda usl toscana sud-est',
#  'grosseto': 'azienda usl toscana sud-est',
#  'siena': 'azienda usl toscana sud-est',
#  'friuli occidentale': 'as friuli occidentale',
#  'a.s.l. della provincia di bergamo': 'asst di bergamo ovest',
#  'triestina': 'asu giuliano isontina',
#  'vicenza': 'azienda ulss n. 8 berica',
#  'verona': 'azienda ulss n. 9 scaligera',
#  'veneziana': 'azienda ulss n. 3 serenissima',
#  'treviso': 'azienda ulss n. 2 marca trevigiana',
#  'thiene': 'azienda ulss n. 7 pedemontana',
#  'to1': "asl citta' di torino",
#  'to2': "asl citta' di torino",
#  'usl 2 - perugia': 'ausl umbria n. 1',
#  'terni': 'ausl umbria n. 2',
#  'sassari': 'asl n. 1 di sassari',
#  'a.s.l. della provincia di brescia': 'ats di brescia',
#  'sanluri': 'asl n. 6 del medio campidano',
#  'a.s.l. della provincia di lodi': 'asst di lodi',
#  'a.s.l. della provincia di mantova': 'asst di mantova',
#  'a.s.l. della provincia di cremona': 'asst di cremona',
#  'rovigo': 'azienda ulss n. 5 polesana',
#  "s. dona' di piave": 'azienda ulss n. 4 veneto orientale',
#  'pieve di soligo': 'azienda ulss n. 2 marca trevigiana',
#  'nuoro': 'asl n. 3 di nuoro',
#  'olbia': 'asl n. 2 della gallura',
#  'rm/a': 'roma 1',
#  'rm/b': 'roma 2',
#  'rm/c': 'roma 2',
#  'rm/d': 'roma 3',
#  'rm/e': 'roma 1',
#  'rm/f': 'roma 4',
#  'rm/g': 'roma 5',
#  'rm/h': 'roma 6',
#  'padova': 'azienda ulss n. 6 euganea',
#  'oristano': 'asl n. 5 di oristano',
#  'a.s.l. della provincia di pavia': 'ats di pavia',
#  'a.s.l. della provincia di sondrio': "asst della valtellina e dell'alto lario",
#  'alto friuli - collinare - medio friuli': 'asu friuli centrale',
#  'alto friuli': 'asu friuli centrale',
#  'friuli centrale': 'asu friuli centrale',
#  'cagliari': 'asl n. 8 di cagliari',
#  'bussolengo': 'azienda ulss n. 9 scaligera',
#  'bassa friulana - isontina': 'asu giuliano isontina',
#  'asl 4 - terni': 'ausl umbria n. 2',
#  'perugia': 'ausl umbria n. 1',
#  'mirano': 'azienda ulss n. 3 serenissima',
#  'legnago': 'azienda ulss n. 9 scaligera',
#  'belluno': 'azienda ulss n. 1 dolomiti',
#  'este monselice montagnana': 'azienda ulss n. 6 euganea',
#  'azienda usl rimini': 'azienda usl della romagna',
#  'azienda usl ravenna': 'azienda usl della romagna',
#  "azienda usl forli'": 'azienda usl della romagna',
#  'azienda usl cesena': 'azienda usl della romagna',
#  'azienda per la tutela della salute': 'asl n. 1 di sassari',
#  'asl n. 2 della gallura': 'asl n. 2 della gallura',
#  "asl 1 - citta' di castello": 'ausl umbria n. 1',
#  'ast1 di pesaro e urbino': 'asur',
#  'ast2 di ancona': 'asur',
#  'ast3 di macerata': 'asur',
#  'ast4 di fermo': 'asur',
#  'ast5 di ascoli piceno': 'asur',
#  'asolo': 'azienda ulss n. 2 marca trevigiana',
#  'a.s.l. della provincia di como': "ats dell'insubria",
#  'a.s.l. della provincia di milano 1': "ats della citta' metropolitana di milano",
#  'a.s.l. della provincia di milano 2': "ats della citta' metropolitana di milano",
#  'a.s.l. di milano': "ats della citta' metropolitana di milano",
#  'a.s.l. della provincia di varese': "ats dell'insubria",
#  'a.s.l. di vallecamonica-sebino': 'asst della valcamonica',
#  'a.s.l. provincia di monza e brianza': 'asst della brianza',
#  'adria': 'azienda ulss n. 5 polesana',
#  'chioggia': 'azienda ulss n. 3 serenissima',
#  'bassano del grappa': 'azienda ulss n. 7 pedemontana',
#  'asl 3 - foligno': 'ausl umbria n. 2',
#  'foligno': 'ausl umbria n. 2',
#  'asl bat': 'asl bt',
#  'arzignano': 'azienda ulss n. 8 berica',
#  'aosta': "azienda u.s.l. valle d'aosta",
#  'asui di trieste': 'asu giuliano isontina',
#  'asui di udine': 'asu friuli centrale',
#  'medio friuli': 'asu friuli centrale',
#  "citta' di castello": 'ausl umbria n. 1',
#  'feltre': 'azienda ulss n. 1 dolomiti',
#  'isontina': 'asu giuliano isontina',
#  'lanusei': "asl n. 4 dell'ogliastra",
#  'monselice': 'azienda ulss n. 6 euganea',
#  'locri': 'a.s.p. reggio calabria',
#  'bassa friulana': 'asu giuliano isontina',
#  'cittadella': 'azienda ulss n. 6 euganea',
#  'a.s.l. della provincia di lecco': 'asst di lecco'}
