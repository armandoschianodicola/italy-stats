# %%
import os
import sys
import shutil

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %%
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from utils import region_formatter, path_utils

# %%
pathUtils = path_utils.PathUtils()

# %%
fig_plots = []

# %%
git_root_path = pathUtils.get_git_root(os.getcwd())
dataframes_path = "{}/dataframes".format(git_root_path)

# %%
# %run ../dataframes/provinces_gdf.ipynb -i
provinces_gdf = pd.read_pickle("{}/provinces_gdf.pkl".format(dataframes_path))

# %%
# %run ../dataframes/asl.ipynb -i
df_asl = pd.read_pickle("{}/df_asl.pkl".format(dataframes_path))

# %%
# %run ../dataframes/dism_first_access.ipynb -i
df_dism_first_access = pd.read_pickle("{}/df_dism_first_access.pkl".format(dataframes_path))

# %%
# %run ../datasets/dism_provincia_mapper.ipynb -i

# %%
newcmp = LinearSegmentedColormap.from_list("", ["#a3b18a", "#588157","#3a5a40"])

# %%
### Constants
OUTPUT_DIR = "output"
TARGET_GROUP = "Ritardo mentale"
TARGET_GROUP_TEXT = "Ritardo mentale"
YEAR = "2022"
# CMAP = (ListedColormap(['cyan', 'yellow', 'orange']))
CMAP = newcmp

# %%
plt.rcParams["figure.figsize"] = [7.50, 5.50]
plt.rcParams["figure.autolayout"] = True

# %%
REGION_COLOURS = {
    "Nord": "#344e41", 
    "Centro": "#588157",
    "Sud e Isole": "#dad7cd",
}

# %%
if not os.path.exists(OUTPUT_DIR):
    # Create the directory
    os.makedirs(OUTPUT_DIR)

# %%
folder = OUTPUT_DIR
for filename in os.listdir(folder):
    file_path = os.path.join(folder, filename)
    try:
        if os.path.isfile(file_path) or os.path.islink(file_path):
            os.unlink(file_path)
        elif os.path.isdir(file_path):
            shutil.rmtree(file_path)
    except Exception as e:
        print('Failed to delete %s. Reason: %s' % (file_path, e))

# %% [markdown]
# # prepare dataframe

# %%
df = df_dism_first_access.loc[df_dism_first_access["gruppo_diagnostico"] == TARGET_GROUP, [
    "codice_asl", 
    "descrizione_regione",
    "sesso",
    "numero_accessi",
    "asl"
]]

# %%
df
# Out:
#       codice_asl descrizione_regione    sesso  numero_accessi  \
# 8            203            PIEMONTE  Maschio             609
# 19           203            PIEMONTE  Femmina             502
# 30           204            PIEMONTE  Maschio             570
# 41           204            PIEMONTE  Femmina             335
# 52           205            PIEMONTE  Maschio             293
# ...          ...                 ...      ...             ...
# 2869         305            SARDEGNA  Femmina              75
# 2879         306            SARDEGNA  Maschio              46
# 2888         306            SARDEGNA  Femmina              36
# 2898         308            SARDEGNA  Maschio             261
# 2908         308            SARDEGNA  Femmina             186
#
#                                asl
# 8                              to3
# 19                             to3
# 30                             to4
# 41                             to4
# 52                             to5
# ...                            ...
# 2869          asl n. 5 di oristano
# 2879  asl n. 6 del medio campidano
# 2888  asl n. 6 del medio campidano
# 2898          asl n. 8 di cagliari
# 2908          asl n. 8 di cagliari
#
# [273 rows x 5 columns]

# %%
df_asl
# Out:
#       anno  codice_regione denominazione_regione  codice_azienda  \
# 0     2010              10              PIEMONTE             201
# 1     2010              10              PIEMONTE             202
# 2     2010              10              PIEMONTE             203
# 3     2010              10              PIEMONTE             204
# 4     2010              10              PIEMONTE             205
# ...    ...             ...                   ...             ...
# 1801  2024             200              SARDEGNA             304
# 1802  2024             200              SARDEGNA             305
# 1803  2024             200              SARDEGNA             306
# 1804  2024             200              SARDEGNA             307
# 1805  2024             200              SARDEGNA             308
#
#              denominazione_azienda                        indirizzo    cap  \
# 0                              to1           VIA S.SECONDO 29        10128
# 1                              to2          CORSO SVIZZERA 164       10149
# 2                              to3  VIA MARTIRI XXX APRILE 30        10093
# 3                              to4                  Via Po 11        10034
# 4                              to5        VIA SAN DOMENICO 21        10023
# ...                            ...                              ...    ...
# 1801       asl n. 4 dell'ogliastra                   VIA PISCINAS 1   8045
# 1802          asl n. 5 di oristano                  VIA CARDUCCI 35   9170
# 1803  asl n. 6 del medio campidano         VIA GIUSEPPE UNGARETTI 9   9025
# 1804           asl n. 7 del sulcis                  VIA DALMAZIA 83   9013
# 1805          asl n. 8 di cagliari    PO MARINO-LUNGOMARE POETTO 12   9126
#
#         comune sigla_provincia     telefono          fax  \
# 0       TORINO              TO          NaN          NaN
# 1       TORINO              TO          NaN          NaN
# 2     COLLEGNO              TO          NaN          NaN
# 3     CHIVASSO              TO          NaN          NaN
# 4       CHIERI              TO          NaN          NaN
# ...        ...             ...          ...          ...
# 1801   LANUSEI              NU          NaN          NaN
# 1802  ORISTANO              OR          NaN          NaN
# 1803   SANLURI              SU     07093841     07093841
# 1804  CARBONIA              SU     07816681     07816681
# 1805  CAGLIARI              CA  070/6097941  070/6097941
#
#                                        e-mail                  sito_web  \
# 0                                         NaN                       NaN
# 1                                         NaN                       NaN
# 2                                         NaN                       NaN
# 3                                         NaN                       NaN
# 4                                         NaN                       NaN
# ...                                       ...                       ...
# 1801       direzione.generale@aslogliastra.it       www.aslogliastra.it
# 1802        direzione.generale@asloristano.it    nuovo.asloristano.it/a
# 1803  direzione.generale@aslmediocampidano.it  www.aslmediocampidano.it
# 1804          direzione.generale@aslsulcis.it          www.aslsulcis.it
# 1805        direzione.generale@aslcagliari.it    nuovo.aslcagliari.it/a
#
#        partita_iva denominazione_azienda_compatibile
# 0              NaN              asl citta' di torino
# 1              NaN              asl citta' di torino
# 2              NaN                               to3
# 3              NaN                               to4
# 4              NaN                               to5
# ...            ...                               ...
# 1801  1.620421e+09           asl n. 4 dell'ogliastra
# 1802  1.258181e+09              asl n. 5 di oristano
# 1803  3.990321e+09      asl n. 6 del medio campidano
# 1804  3.990311e+09               asl n. 7 del sulcis
# 1805  3.990561e+09              asl n. 8 di cagliari
#
# [1806 rows x 15 columns]

# %%
df_asl = df_asl[["anno", "comune", "codice_azienda", "sigla_provincia", "denominazione_azienda_compatibile"]]

# %%
df_asl = df_asl.groupby(['denominazione_azienda_compatibile', "comune", "sigla_provincia"])['anno'].max().reset_index()

# %%
df_asl
# Out:
#     denominazione_azienda_compatibile          comune sigla_provincia  anno
# 0                     a.s.l. avellino        AVELLINO              AV  2024
# 1                    a.s.l. benevento       BENEVENTO              BN  2024
# 2                      a.s.l. caserta         CASERTA              CE  2024
# 3              a.s.l. napoli 1 centro          NAPOLI              NA  2024
# 4                a.s.l. napoli 2 nord  FRATTAMAGGIORE              NA  2024
# ..                                ...             ...             ...   ...
# 161                               to5          CHIERI              TO  2024
# 162                            trento          TRENTO              TN  2024
# 163                                vc        VERCELLI              VC  2024
# 164                               vco          OMEGNA              VB  2024
# 165                           viterbo         VITERBO              VT  2024
#
# [166 rows x 4 columns]

# %%
provinces_gdf = provinces_gdf[["prov_acr", "geometry", "zone", "prov_name"]]

# %%
df_incompatible_names = df.set_index("asl").join(df_asl.set_index("denominazione_azienda_compatibile"), how="right").reset_index()

# %%
missing_asl_mask = df_incompatible_names.numero_accessi.isna()

# %%
df_incompatible_names.loc[missing_asl_mask, ]
# Out:
#                         asl  codice_asl descrizione_regione sesso  \
# 50   asl n. 2 della gallura         NaN                 NaN   NaN
# 51   asl n. 2 della gallura         NaN                 NaN   NaN
# 64      asl n. 7 del sulcis         NaN                 NaN   NaN
# 331                carbonia         NaN                 NaN   NaN
# 332                carbonia         NaN                 NaN   NaN
#
#      numero_accessi    comune sigla_provincia  anno
# 50              NaN     OLBIA              OT  2016
# 51              NaN     OLBIA              SS  2024
# 64              NaN  CARBONIA              SU  2024
# 331             NaN  CARBONIA              CI  2016
# 332             NaN  IGLESIAS              CI  2010

# %%
df = df.set_index("asl").join(df_asl.set_index("denominazione_azienda_compatibile"))

# %%
df
# Out:
#                               codice_asl descrizione_regione    sesso  \
# asl
# to3                                  203            PIEMONTE  Maschio
# to3                                  203            PIEMONTE  Femmina
# to4                                  204            PIEMONTE  Maschio
# to4                                  204            PIEMONTE  Femmina
# to5                                  205            PIEMONTE  Maschio
# ...                                  ...                 ...      ...
# asl n. 6 del medio campidano         306            SARDEGNA  Femmina
# asl n. 8 di cagliari                 308            SARDEGNA  Maschio
# asl n. 8 di cagliari                 308            SARDEGNA  Maschio
# asl n. 8 di cagliari                 308            SARDEGNA  Femmina
# asl n. 8 di cagliari                 308            SARDEGNA  Femmina
#
#                               numero_accessi     comune sigla_provincia  \
# asl
# to3                                      609   COLLEGNO              TO
# to3                                      502   COLLEGNO              TO
# to4                                      570   CHIVASSO              TO
# to4                                      335   CHIVASSO              TO
# to5                                      293     CHIERI              TO
# ...                                      ...        ...             ...
# asl n. 6 del medio campidano              36    SANLURI              VS
# asl n. 8 di cagliari                     261   CAGLIARI              CA
# asl n. 8 di cagliari                     261  SELARGIUS              CA
# asl n. 8 di cagliari                     186   CAGLIARI              CA
# asl n. 8 di cagliari                     186  SELARGIUS              CA
#
#                                 anno
# asl
# to3                           2024.0
# to3                           2024.0
# to4                           2024.0
# to4                           2024.0
# to5                           2024.0
# ...                              ...
# asl n. 6 del medio campidano  2016.0
# asl n. 8 di cagliari          2024.0
# asl n. 8 di cagliari          2022.0
# asl n. 8 di cagliari          2024.0
# asl n. 8 di cagliari          2022.0
#
# [423 rows x 7 columns]

# %%
df = df.reset_index()

# %%
missing_mask_sigla_provincia = df['sigla_provincia'].isna()

# %%
df.loc[missing_mask_sigla_provincia,]
# Out:
#                                           asl  codice_asl descrizione_regione  \
# 50   asst grande ospedale metropolitano nigua         701           LOMBARDIA
# 51   asst grande ospedale metropolitano nigua         701           LOMBARDIA
# 52                   asst santi paolo e carlo         702           LOMBARDIA
# 53                   asst santi paolo e carlo         702           LOMBARDIA
# 54                asst fatebenefratelli sacco         703           LOMBARDIA
# 55                asst fatebenefratelli sacco         703           LOMBARDIA
# 56                        asst ovest milanese         705           LOMBARDIA
# 57                        asst ovest milanese         705           LOMBARDIA
# 58                              asst rhodense         706           LOMBARDIA
# 59                              asst rhodense         706           LOMBARDIA
# 60                           asst nord milano         707           LOMBARDIA
# 61                           asst nord milano         707           LOMBARDIA
# 62           asst melegnano e della martesana         708           LOMBARDIA
# 63           asst melegnano e della martesana         708           LOMBARDIA
# 66                       asst dei sette laghi         710           LOMBARDIA
# 67                       asst dei sette laghi         710           LOMBARDIA
# 68                     asst della valle olona         711           LOMBARDIA
# 69                     asst della valle olona         711           LOMBARDIA
# 70                               asst lariana         712           LOMBARDIA
# 71                               asst lariana         712           LOMBARDIA
# 78                              asst di monza         716           LOMBARDIA
# 79                              asst di monza         716           LOMBARDIA
# 82                   asst papa giovanni xxiii         718           LOMBARDIA
# 83                   asst papa giovanni xxiii         718           LOMBARDIA
# 86                        asst di bergamo est         720           LOMBARDIA
# 87                        asst di bergamo est         720           LOMBARDIA
# 88       asst degli spedali civili di brescia         721           LOMBARDIA
# 89       asst degli spedali civili di brescia         721           LOMBARDIA
# 90                    asst della franciacorta         722           LOMBARDIA
# 91                    asst della franciacorta         722           LOMBARDIA
# 92                             asst del garda         723           LOMBARDIA
# 93                             asst del garda         723           LOMBARDIA
# 98                              asst di crema         726           LOMBARDIA
# 99                              asst di crema         726           LOMBARDIA
# 100                             asst di pavia         727           LOMBARDIA
# 101                             asst di pavia         727           LOMBARDIA
# 102  fondaz.irccs ca' granda - ospedale maggi         925           LOMBARDIA
# 103  fondaz.irccs ca' granda - ospedale maggi         925           LOMBARDIA
# 152     azienda ospedale - universita' padova         901              VENETO
#
#        sesso  numero_accessi comune sigla_provincia  anno
# 50   Maschio             415    NaN             NaN   NaN
# 51   Femmina             242    NaN             NaN   NaN
# 52   Maschio             465    NaN             NaN   NaN
# 53   Femmina             281    NaN             NaN   NaN
# 54   Maschio             445    NaN             NaN   NaN
# 55   Femmina             225    NaN             NaN   NaN
# 56   Maschio             498    NaN             NaN   NaN
# 57   Femmina             370    NaN             NaN   NaN
# 58   Maschio             259    NaN             NaN   NaN
# 59   Femmina             176    NaN             NaN   NaN
# 60   Maschio             363    NaN             NaN   NaN
# 61   Femmina             234    NaN             NaN   NaN
# 62   Maschio             459    NaN             NaN   NaN
# 63   Femmina             452    NaN             NaN   NaN
# 66   Maschio             277    NaN             NaN   NaN
# 67   Femmina             198    NaN             NaN   NaN
# 68   Maschio             741    NaN             NaN   NaN
# 69   Femmina             544    NaN             NaN   NaN
# 70   Maschio             482    NaN             NaN   NaN
# 71   Femmina             258    NaN             NaN   NaN
# 78   Maschio             219    NaN             NaN   NaN
# 79   Femmina             166    NaN             NaN   NaN
# 82   Maschio             504    NaN             NaN   NaN
# 83   Femmina             303    NaN             NaN   NaN
# 86   Maschio             467    NaN             NaN   NaN
# 87   Femmina             379    NaN             NaN   NaN
# 88   Maschio             547    NaN             NaN   NaN
# 89   Femmina             324    NaN             NaN   NaN
# 90   Maschio             147    NaN             NaN   NaN
# 91   Femmina              81    NaN             NaN   NaN
# 92   Maschio             128    NaN             NaN   NaN
# 93   Femmina             110    NaN             NaN   NaN
# 98   Maschio             134    NaN             NaN   NaN
# 99   Femmina             147    NaN             NaN   NaN
# 100  Maschio             705    NaN             NaN   NaN
# 101  Femmina             562    NaN             NaN   NaN
# 102  Maschio             125    NaN             NaN   NaN
# 103  Femmina             140    NaN             NaN   NaN
# 152  Maschio               4    NaN             NaN   NaN

# %%
df.loc[missing_mask_sigla_provincia, 'sigla_provincia'] = df.loc[missing_mask_sigla_provincia, 'asl'].str.lower().map(dism_provincia_map)

# %%
missing_mask_sigla_provincia = df['sigla_provincia'].isna()

# %%
df.loc[missing_mask_sigla_provincia, ]
# Out:
# Empty DataFrame
# Columns: [asl, codice_asl, descrizione_regione, sesso, numero_accessi, comune, sigla_provincia, anno]
# Index: []

# %%
df_dism_agg = df.reset_index()[["asl", "sigla_provincia"]].pivot_table(
    index='sigla_provincia',
    aggfunc='count',
)

# %%
df_dism_agg
# Out:
#                  asl
# sigla_provincia
# AG                 2
# AL                 4
# AN                10
# AO                 2
# AP                10
# ...              ...
# VI                 8
# VR                 6
# VS                 2
# VT                 2
# VV                 2
#
# [108 rows x 1 columns]

# %%
df_dism_agg = df_dism_agg.rename(columns={
    "asl": "dism_count",
})

# %%
df_dism_agg.filter(items=['LI'], axis=0)
# Out:
#     dism_count
# LI           2

# %%
df = df.reset_index()

# %%
df = df.pivot_table(
    index='sigla_provincia',
    aggfunc='sum',
    values='numero_accessi'
)

# %%
df
# Out:
#                  numero_accessi
# sigla_provincia
# AG                          548
# AL                         1560
# AN                         1330
# AO                          183
# AP                         1330
# ...                         ...
# VI                         2264
# VR                         2841
# VS                           82
# VT                          213
# VV                          100
#
# [108 rows x 1 columns]

# %%
df = df.join(df_dism_agg)

# %%
df = df.assign(target_group_avg=lambda df_: df_.numero_accessi / df_.dism_count)

# %%
df
# Out:
#                  numero_accessi  dism_count  target_group_avg
# sigla_provincia
# AG                          548           2             274.0
# AL                         1560           4             390.0
# AN                         1330          10             133.0
# AO                          183           2              91.5
# AP                         1330          10             133.0
# ...                         ...         ...               ...
# VI                         2264           8             283.0
# VR                         2841           6             473.5
# VS                           82           2              41.0
# VT                          213           2             106.5
# VV                          100           2              50.0
#
# [108 rows x 3 columns]

# %%
df = provinces_gdf.set_index("prov_acr").join(df)

# %%
df
# Out:
#                                                    geometry         zone  \
# prov_acr
# TO        POLYGON ((7.89397 45.58222, 7.89654 45.57985, ...         Nord
# VC        POLYGON ((7.92900 45.74244, 7.92584 45.74196, ...         Nord
# NO        POLYGON ((8.42079 45.82981, 8.42028 45.83010, ...         Nord
# CN        MULTIPOLYGON (((6.94540 44.42794, 6.94734 44.4...         Nord
# AT        POLYGON ((7.96685 45.11667, 7.96729 45.11673, ...         Nord
# ...                                                     ...          ...
# SS        MULTIPOLYGON (((9.46502 40.65584, 9.46475 40.6...  Sud e Isole
# NU        MULTIPOLYGON (((9.28037 39.91741, 9.27741 39.9...  Sud e Isole
# CA        MULTIPOLYGON (((8.84872 39.09924, 8.84697 39.1...  Sud e Isole
# OR        MULTIPOLYGON (((8.78200 40.18982, 8.78829 40.1...  Sud e Isole
# SU        MULTIPOLYGON (((8.50222 39.71303, 8.50016 39.7...  Sud e Isole
#
#              prov_name  numero_accessi  dism_count  target_group_avg
# prov_acr
# TO              Torino          4535.0         8.0           566.875
# VC            Vercelli           428.0         2.0           214.000
# NO              Novara           783.0         2.0           391.500
# CN               Cuneo          1335.0         4.0           333.750
# AT                Asti           282.0         2.0           141.000
# ...                ...             ...         ...               ...
# SS             Sassari           255.0         2.0           127.500
# NU               Nuoro           176.0         4.0            44.000
# CA            Cagliari           894.0         4.0           223.500
# OR            Oristano           154.0         2.0            77.000
# SU        Sud Sardegna            82.0         2.0            41.000
#
# [107 rows x 6 columns]

# %%
plot_title = "Totale accessi con diagnosi '{}'\n per DSM per provincia - Anno {}".format(
    TARGET_GROUP_TEXT,
    YEAR
)

# %%
df_plot = df.plot(
    column="numero_accessi",
    legend=True,
    cmap=CMAP,
    edgecolor="black",
    linewidth=0.3,
    missing_kwds={
        "color": "white",
        "edgecolor": "black",
        "label": "Missing values",
    }
);
plt.title(plot_title)
df_plot.set_axis_off()
plt.annotate('fonte: Ministero della salute', (0,0), (140, -10), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('*dati mancanti riportati in bianco', (0,0), (140, -25), xycoords='axes fraction', textcoords='offset points', va='top', style='italic')
fig_plots.append({
    "df": df_plot,
    "name": plot_title
})

# %%
best_rows = df.sort_values(by=['numero_accessi'], ascending=False).head(15)
best_rows_sorted = best_rows.sort_values(by=['numero_accessi'])
df_plot = best_rows_sorted.plot.barh(
    title=plot_title,
    y="numero_accessi",
    x="prov_name",
    ylabel='Province',
    color=best_rows_sorted['zone'].replace(REGION_COLOURS)
).legend(
    [
        Patch(facecolor=REGION_COLOURS['Nord']),
        Patch(facecolor=REGION_COLOURS['Centro']),
        Patch(facecolor=REGION_COLOURS['Sud e Isole']),
    ], ["Nord", "Centro", 'Sud e Isole']
)
plt.annotate('fonte: Ministero della salute', (0,0), (260, -30), xycoords='axes fraction', textcoords='offset points', va='top')
fig_plots.append({
    "df": df_plot,
    "name": plot_title
})

# %%
best_rows
# Out:
#                                                    geometry         zone  \
# prov_acr
# FC        POLYGON ((11.95117 43.78699, 11.95053 43.78787...       Centro
# MI        MULTIPOLYGON (((8.84290 45.39384, 8.84219 45.3...         Nord
# PD        POLYGON ((11.98296 45.16275, 11.98343 45.15557...         Nord
# PG        MULTIPOLYGON (((13.15849 42.65425, 13.15764 42...       Centro
# LU        POLYGON ((10.70536 43.84269, 10.70666 43.84232...       Centro
# TO        POLYGON ((7.89397 45.58222, 7.89654 45.57985, ...         Nord
# NA        MULTIPOLYGON (((14.35567 41.00178, 14.35628 41...  Sud e Isole
# CT        MULTIPOLYGON (((15.16620 37.55927, 15.16576 37...  Sud e Isole
# TV        POLYGON ((11.80324 45.79994, 11.79414 45.79929...         Nord
# VE        POLYGON ((12.65668 45.79134, 12.66165 45.79243...         Nord
# BO        POLYGON ((11.13161 44.56743, 11.12953 44.56816...       Centro
# RN        POLYGON ((12.45240 44.10959, 12.45333 44.11075...       Centro
# RA        POLYGON ((11.88393 44.57916, 11.88897 44.58038...       Centro
# VR        POLYGON ((11.33151 45.38763, 11.33084 45.38717...         Nord
# PU        MULTIPOLYGON (((12.50082 43.51963, 12.50008 43...       Centro
#
#                 prov_name  numero_accessi  dism_count  target_group_avg
# prov_acr
# FC           Forlì-Cesena          6066.0        12.0        505.500000
# MI                 Milano          5899.0        22.0        268.136364
# PD                 Padova          5488.0         9.0        609.777778
# PG                Perugia          5049.0         8.0        631.125000
# LU                  Lucca          4761.0         6.0        793.500000
# TO                 Torino          4535.0         8.0        566.875000
# NA                 Napoli          4403.0        10.0        440.300000
# CT                Catania          3990.0         2.0       1995.000000
# TV                Treviso          3672.0         6.0        612.000000
# VE                Venezia          3450.0         8.0        431.250000
# BO                Bologna          3389.0         4.0        847.250000
# RN                 Rimini          3033.0         6.0        505.500000
# RA                Ravenna          3033.0         6.0        505.500000
# VR                 Verona          2841.0         6.0        473.500000
# PU        Pesaro e Urbino          2660.0        20.0        133.000000

# %%
plot_title = "Media accessi con diagnosi '{}'\n per DSM per provincia - Anno {}".format(
    TARGET_GROUP_TEXT,
    YEAR
)

# %%
df_plot = df.plot(
    column="target_group_avg",
    legend=True,
    cmap=CMAP,
    edgecolor="black",
    linewidth=0.3,
    missing_kwds={
        "color": "white",
        "edgecolor": "black",
        "label": "Missing values",
    }
);
plt.title(plot_title)
df_plot.set_axis_off()
plt.annotate('fonte: Ministero della salute', (0,0), (140, -10), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('*dati mancanti riportati in bianco', (0,0), (140, -25), xycoords='axes fraction', textcoords='offset points', va='top', style='italic')
fig_plots.append({
    "df": df_plot,
    "name": plot_title
})

# %%
best_rows = df.sort_values(by=['target_group_avg'], ascending=False).head(15)
best_rows_sorted = best_rows.sort_values(by=['target_group_avg'])
df_plot = best_rows_sorted.plot.barh(
    title=plot_title,
    x="prov_name",
    y="target_group_avg",
    ylabel='Province',
    color=best_rows_sorted['zone'].replace(REGION_COLOURS)
).legend(
    [
        Patch(facecolor=REGION_COLOURS['Nord']),
        Patch(facecolor=REGION_COLOURS['Centro']),
        Patch(facecolor=REGION_COLOURS['Sud e Isole']),
    ], ["Nord", "Centro", 'Sud e Isole']
)
plt.annotate('fonte: Ministero della salute', (0,0), (260, -30), xycoords='axes fraction', textcoords='offset points', va='top')
fig_plots.append({
    "df": df_plot,
    "name": plot_title
})

# %%
plot_title = "Numero di DSM per provincia - Anno {}".format(
    YEAR
)

# %%
df_plot = df.plot(
    column="dism_count",
    legend=True,
    cmap=CMAP,
    edgecolor="black",
    linewidth=0.3,
    missing_kwds={
        "color": "white",
        "edgecolor": "black",
        "label": "Missing values",
    }
);
plt.title(plot_title)
df_plot.set_axis_off()
plt.annotate('fonte: Ministero della salute', (0,0), (140, -10), xycoords='axes fraction', textcoords='offset points', va='top')
plt.annotate('*dati mancanti riportati in bianco', (0,0), (140, -25), xycoords='axes fraction', textcoords='offset points', va='top', style='italic')
fig_plots.append({
    "df": df_plot,
    "name": plot_title
})

# %%
best_rows = df.sort_values(by=['dism_count'], ascending=False).head(15)
best_rows_sorted = best_rows.sort_values(by=['dism_count'])
df_plot = best_rows_sorted.plot.barh(
    title=plot_title,
    x="prov_name",
    y="dism_count",
    ylabel='Province',
    color=best_rows_sorted['zone'].replace(REGION_COLOURS)
).legend(
    [
        Patch(facecolor=REGION_COLOURS['Nord']),
        Patch(facecolor=REGION_COLOURS['Centro']),
        Patch(facecolor=REGION_COLOURS['Sud e Isole']),
    ], ["Nord", "Centro", 'Sud e Isole']
)
plt.annotate('fonte: Ministero della salute', (0,0), (260, -30), xycoords='axes fraction', textcoords='offset points', va='top')
fig_plots.append({
    "df": df_plot,
    "name": plot_title
})

# %%
for i, fig_plot in enumerate(fig_plots, start=1):
    df_ = fig_plot.get("df")
    df_name = fig_plot.get("name")
    file_name = "{}/{}_{}.png".format(OUTPUT_DIR, i, df_name)
    df_.get_figure().savefig(file_name)
